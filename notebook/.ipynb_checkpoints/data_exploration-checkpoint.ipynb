# %%
import pandas

# %%
pandas.read_csv('../data/Study_A.csv', dtype={'Study': 'category', 'Country': 'category', 'TxGroup': 'category', 'LeadStatus': 'category'})
# Out:
#      Study Country  PatientID  SiteID  RaterID  AssessmentiD  TxGroup  \
# 0        A     USA      10001   20035    30076        100679  Control
# 1        A     USA      10001   20035    30076        101017  Control
# 2        A     USA      10001   20035    30076        102177  Control
# 3        A     USA      10001   20035    30076        101533  Control
# 4        A     USA      10001   20035    30076        100930  Control
# ...    ...     ...        ...     ...      ...           ...      ...
# 2398     A     USA      10351   20004    30039        101959  Control
# 2399     A     USA      10351   20004    30039        101215  Control
# 2400     A     USA      10351   20004    30039        100903  Control
# 2401     A     USA      10351   20004    30039        101955  Control
# 2402     A     USA      10351   20004    30068        100700  Control
#
#       VisitDay  P1  P2  ...  G9  G10  G11  G12  G13  G14  G15  G16  \
# ...
